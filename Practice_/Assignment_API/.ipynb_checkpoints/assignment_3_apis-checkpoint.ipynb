# %% [markdown]
# <h2 align="center" style="color:blue">Codebasics Python Course: Exercise - APIs in Python</h2>

# %% [markdown]
# The Open Brewery DB API offers detailed data on various breweries across the United States.
#
# --
#
# ### Task 1: Fetch Brewery Data for Non-alcoholic Drink manufacturer - US client
#
# **Scenario:**
#
# As Tony Sharma mentioned during the call, he needs details about all the breweries in a specific state.
#
# Your task is to use the Open Brewery DB API to fetch and display brewery details based on a given state, which will be helpful for his client call tomorrow.
#
# **Write a Python program that:**
#
# 1. Uses the `requests` library to call the Open Brewery DB API to fetch brewery data based on a given state.
# 2. Parses the JSON response.
# 3. Extracts and displays the name, type, and location (city) of each brewery.
# 4. Handles errors gracefully (e.g., network issues or invalid API requests).
#
# Example URL for Texas Breweries: `https://api.openbrewerydb.org/breweries?by_state=texas`

# %%
# write your code here
import requests

def get_breweries_by_state(state):    
    url = f'https://api.openbrewerydb.org/v1/breweries?by_state={state}'
    
    try:
        response = requests.get(url)
        response.raise_for_status()
        
        breweries = response.json()
        breweries
        if not breweries:
            print("No breweries found in the specified state.")
            return
         
        print(f'The Breweries of {state} are: ')
        print()
        
        for brewery in breweries:
            name = brewery.get('name', 'N/A')
            brewery_type = brewery.get('brewery_type','N/A')
            city = brewery.get('city','N/A')
        
            print(name)
            print(brewery_type)
            print(city)
            print('-' * 40)
            
    except requests.exceptions.RequestException as e:
        print(f'Error Occurred: {e}')

state_name = input("Type a State Name of US: ")
get_breweries_by_state(state_name)
# Out:
# Type a State Name of US:  Texas
# The Breweries of Texas are:
#
# (512) Brewing Co
# micro
# Austin
# ----------------------------------------
# 11 Below Brewing Company
# micro
# Houston
# ----------------------------------------
# 28th State Brewing
# planning
# Houston
# ----------------------------------------
# 3 Nations Brewing
# micro
# Farmers Branch
# ----------------------------------------
# 4J Brewing Company
# micro
# Houston
# ----------------------------------------
# 4th Tap Brewing Cooperative
# micro
# Austin
# ----------------------------------------
# 5 Stones Artisan Brewery
# micro
# New Braunfels
# ----------------------------------------
# 5th Element Brewing
# planning
# Leander
# ----------------------------------------
# 5x5 Brewing Co.
# planning
# Mission
# ----------------------------------------
# 8th Wonder Brewery
# micro
# Houston
# ----------------------------------------
# 903 Brewers
# micro
# Sherman
# ----------------------------------------
# Acopon Brewing Co
# micro
# Dripping Springs
# ----------------------------------------
# Adelbert's Brewery LLC
# micro
# Austin
# ----------------------------------------
# Alamo Beer Co
# micro
# San Antonio
# ----------------------------------------
# Alcazar Brewery, LLC.
# planning
# Rio Grande City
# ----------------------------------------
# Altmeyer and Lewis Brewing Company
# micro
# San Marcos
# ----------------------------------------
# Altstadt Brewery
# micro
# Fredericksburg
# ----------------------------------------
# Angelina Brewing Company, LLC.
# planning
# Lufkin
# ----------------------------------------
# Anheuser-Busch Inc â Houston
# large
# Houston
# ----------------------------------------
# Anvil Brewing
# brewpub
# Pittsburg
# ----------------------------------------
# Aquabrew
# brewpub
# San Marcos
# ----------------------------------------
# Aransas Pass Brewing Company, LLC
# planning
# Aransas Pass
# ----------------------------------------
# Armadillo Ale Works
# micro
# Denton
# ----------------------------------------
# Astral Brewing
# micro
# Houston
# ----------------------------------------
# Athens Brewing Co
# brewpub
# Athens
# ----------------------------------------
# Austin Beerworks
# regional
# Austin
# ----------------------------------------
# B and J's Handcrafted Texas Ales
# micro
# Corpus Christi
# ----------------------------------------
# B-52 Brewing
# micro
# Conroe
# ----------------------------------------
# B-CS  Zoigl Brewery
# micro
# Bryan
# ----------------------------------------
# Baa Baa Brewhouse
# micro
# Brookshire
# ----------------------------------------
# Back Pew Brewing
# micro
# Porter
# ----------------------------------------
# Back Unturned Brewing Co.
# micro
# San Antonio
# ----------------------------------------
# BackStory Brewery
# planning
# Sulphur Springs
# ----------------------------------------
# Baileson Brewing Company, LLC
# micro
# Houston
# ----------------------------------------
# BAKFISH Brewing Company
# micro
# Pearland
# ----------------------------------------
# Bandera Ale Project, LLC
# micro
# Bandera
# ----------------------------------------
# Bankhead Brewing Company
# brewpub
# Rowlett
# ----------------------------------------
# Bar D Brew House
# brewpub
# San Saba
# ----------------------------------------
# Bare Arms Brewing
# micro
# Waco
# ----------------------------------------
# Barking Armadillo Brewing
# micro
# Georgetown
# ----------------------------------------
# Barrel Assembly
# planning
# Austin
# ----------------------------------------
# Barrow Brewing Company
# micro
# Salado
# ----------------------------------------
# Basement Brewers of Texas
# micro
# Kerrville
# ----------------------------------------
# Batch Craft Beer and Kolaches
# planning
# Austin
# ----------------------------------------
# BattleHops Brewing
# planning
# Katy
# ----------------------------------------
# Bearded Fox Brewing Co.
# micro
# Tomball
# ----------------------------------------
# Beerfoot Beach Bar
# micro
# Galveston
# ----------------------------------------
# Big Bend Brewing Co
# micro
# Alpine
# ----------------------------------------
# Big River Brewery, LLC
# micro
# Pharr
# ----------------------------------------
# Big Texan Brewery
# brewpub
# Amarillo
# ----------------------------------------

# %% [markdown]
# JSONPlaceholder offers a set of APIs for typical CRUD (Create, Read, Update, Delete) operations, making it an excellent resource for learning and testing HTTP requests.
#
# --
#
# ### Task 2: Fetch User Data for AtliQ Client Project
#
# **Scenario:** As a quick favor, Loki shared an ad-hoc task with you. He needs help with a user profile component for an Atliq client application, using JSONPlaceholder to simulate fetching user data.
#
# **Objective:** Create a function `fetch_user_data` that uses JSONPlaceholder’s API to retrieve and format user details.
#
# **Steps:**
#
# 1. Fetch user data from JSONPlaceholder.
# 2. Format the data to include 'name', 'email', and 'address'.
# 3. Return the data as a dictionary.
#
# **Expected Output:**
#
# ```
# {
#     'name': 'Leanne Graham',
#     'email': 'Sincere@april.biz',
#     'address': 'Kulas Light, Gwenborough'
# }
#
#
#
# ```

# %%
# write your code here
def fetch_user_data(user_id):
    url = f"https://jsonplaceholder.typicode.com/users/{user_id}"
    
    try:
        response = requests.get(url)
        response.raise_for_status()
        
        user = response.json()
        
        # Format required fields
        formatted_data = {
            "name": user.get("name", "N/A"),
            "email": user.get("email", "N/A"),
            "address": {
                "street": user.get("address", {}).get("street", "N/A"),
                "city": user.get("address", {}).get("city", "N/A"),
                "zipcode": user.get("address", {}).get("zipcode", "N/A")
            }
        }
        
        return formatted_data
    
    except requests.exceptions.RequestException as e:
        return {"error": str(e)}


# Example usage
data = fetch_user_data(1)
print(data)
# Out:
# {'name': 'Leanne Graham', 'email': 'Sincere@april.biz', 'address': {'street': 'Kulas Light', 'city': 'Gwenborough', 'zipcode': '92998-3874'}}
